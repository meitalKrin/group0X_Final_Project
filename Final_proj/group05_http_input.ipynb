# %%
import pandas as pd

# %%
df = pd.read_csv('group05_http_input.csv')

# %%
print("Application Layer Data Loaded:")
# Out:
# Application Layer Data Loaded:

# %%
print(df.head())
# Out:
# Empty DataFrame
# Columns: [msg_id, app_protocol, src_app, dst_app, message, timestamp]
# Index: []
